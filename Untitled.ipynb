# %%
import pandas as pd

# %%
pd.read_excel('data/MonoAlg-ExperimentMap-AprMay2019.xlsx')
# Out:
#    Experiment no.   Experiment Name:  17052019_algMono0.1_20190519 Unnamed: 3  \
# 0             NaN             Date/s:                1505-17052019        NaN
# 1              R1  Channel identifier               Position (pos)     Strain
# 2             NaN                   1                            1      13B01
# 3             NaN                   1                            2      13B01
# 4             NaN                   1                            3      13B01
# 5             NaN                   1                            4      13B01
# 6             NaN                   1                            5      13B01
# 7             NaN                   1                            6      13B01
# 8             NaN                   1                            7      13B01
# 9             NaN                   1                            8      13B01
# 10            NaN                   2                            9       1C10
# ...

# %%
pd.read_csv('data/Lineage/llastik_tracking_csv/Tracking_27112018.h5.csv')
# Out:
#       frame  labelimageId  trackId  lineageId  parentTrackId  mergerLabelId  \
# 0         0             1       -1         -1              0              0
# 1         0             2        2          2              0              0
# 2         0             3       -1         -1              0              0
# 3         0             4        3          3              0              0
# 4         0             5       -1         -1              0              0
# 5         0             6        4          4              0              0
# 6         0             7        5          5              0              0
# 7         0             8        6          6              0              0
# 8         0             9       -1         -1              0              0
# 9         0            10       -1         -1              0              0
# 10        0            11        7          7              0              0
# ...
