# %%
import sys
sys.path.append('../src')


import os
from skimage import io

import matplotlib.pyplot as plt

from unet_prediction import SegmentationPredictor
# Out:
# Using TensorFlow backend.

# %%
path = '/cluster/work/sis/cdss/oschmanf/ackermann-bacteria-segmentation/data/unet/family_machine/'
cell_types = os.listdir(path)
print(cell_types)
# Out:
# ['CB15-WT', 'FS144', 'CB15-flgH', 'Phase', 'SwCWRt00xy25_RawImage.tif', 'ZF270g', 'Ecoli']

# %% [markdown]
# # CB15-WT

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_CB15-WT_new_w.h5')
img_name = path + 'CB15-WT/test/img/Cb15WT_frame110.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-WT/test/seg/Cb15WT_frame110_seg_new_w.png', pred.fig)

# %%
img_name = path + 'CB15-WT/test/img/Cb15WT_frame160.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-WT/test/seg/Cb15WT_frame160_seg_new_w.png', pred.fig)

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_CB15-WT_trans.h5')
img_name = path + 'CB15-WT/test/img/Cb15WT_frame110.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-WT/test/seg/Cb15WT_frame110_seg_trans.png', pred.fig)

# %%
img_name = path + 'CB15-WT/test/img/Cb15WT_frame160.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-WT/test/seg/Cb15WT_frame160_seg_trans.png', pred.fig)

# %% [markdown]
# # CB15-flgH

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_CB15-flgH_new_w.h5')
img_name = path + 'CB15-flgH/test/img/CB-FlgH_frame110.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-flgH/test/seg/CB15FlgH_frame110_seg_new_w.png', pred.fig)

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_CB15-flgH_trans.h5')
img_name = path + 'CB15-flgH/test/img/CB-FlgH_frame110.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'CB15-flgH/test/seg/CB15FlgH_frame110_seg_trans.png', pred.fig)

# %% [markdown]
# # E. coli

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_Ecoli_trans.h5')
img_name = '../data/data_Emanuele/pos14-g_100_cut.tif'

# predict segmentation
pred.predict_single_image(img_name)

# # save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'Ecoli/test/seg/pos14-p_frame10_seg_trans.png', pred.fig)

# %% [markdown]
# # FS144

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_FS144_new_w.h5')
img_name = path + 'FS144/test/img/pos33-mCherry_dual-A10100_cut.png'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'FS144/test/seg/pos33-mCherry_dual-A10100_seg_new.png', pred.fig)

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_FS144_trans.h5')
img_name = path + 'FS144/test/img/pos33-mCherry_dual-A10100_cut.png'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'FS144/test/seg/pos33-mCherry_dual-A10100_seg_trans.png', pred.fig)

# %% [markdown]
# # ZF270g

# %%
pred = SegmentationPredictor('../model_weights/family_machine/model_weights_ZF270g.h5')
img_name = path + 'ZF270g/test/img/pos33-eGFP_dual-A10100_cut.png'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'ZF270g/test/seg/pos33-eGFP_dual-A10100_seg.png', pred.fig)
