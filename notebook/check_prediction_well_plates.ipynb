# %%
import sys
sys.path.append('../src')


import os
from skimage import io

import matplotlib.pyplot as plt

from unet_prediction import SegmentationPredictor
# Out:
# Using TensorFlow backend.

# %%
path = '/cluster/work/sis/cdss/oschmanf/ackermann-bacteria-segmentation/data/unet/well_plate/'
cell_types = os.listdir(path)
print(cell_types)
# Out:
# ['ZF270', '13B01', '12B01']

# %% [markdown]
# # ZF270

# %%
pred = SegmentationPredictor('../model_weights/well_plate/model_weights_ZF270WithWeighting.h5')
img_name = path + 'ZF270/test/img/Well2_frame110.png'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + 'ZF270/test/seg/Well2_frame110_seg.png', pred.fig)

# %% [markdown]
# # 13B01

# %%
pred = SegmentationPredictor('../model_weights/well_plate/model_weights_13B01.h5')
img_name = path + '13B01/test/img/13B01dsRED_frame89.tif'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame89_seg.png', pred.fig)
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame89_seg_bin.png', pred.seg)
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame89_seg_label.png', pred.seg_label)
# Out:
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 312]. Convert image to uint8 prior to saving to suppress this warning.

# %%
pred = SegmentationPredictor('../model_weights/well_plate/model_weights_13B01.h5')
img_name = path + '13B01/test/img/13B01dsRED_frame61.tif'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame61_seg.png', pred.fig)
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame61_seg_bin.png', pred.seg)
pred.save_segmentation_image(path + '13B01/test/seg/13B01dsRED_frame61_seg_label.png', pred.seg_label)
# Out:
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 44]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# # 12B01

# %%
pred = SegmentationPredictor('../model_weights/well_plate/model_weights_12B01.h5')
img_name = path + '12B01/test/img/12B01dsRED_frame100.tif'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame100_seg.png', pred.fig)
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame100_seg_bin.png', pred.seg)
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame100_seg_label.png', pred.seg_label)
# Out:
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 300]. Convert image to uint8 prior to saving to suppress this warning.

# %%
pred = SegmentationPredictor('../model_weights/well_plate/model_weights_12B01.h5')
img_name = path + '12B01/test/img/12B01dsRED_frame167.tif'

# predict segmentation
pred.predict_single_image(img_name)

# save segmentation
pred.generate_segmentation_overlay()
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame167_seg.png', pred.fig)
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame167_seg_bin.png', pred.seg)
pred.save_segmentation_image(path + '12B01/test/seg/12B01dsRED_frame167_seg_label.png', pred.seg_label)
# Out:
# Lossy conversion from int64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int64 to uint8. Range [0, 395]. Convert image to uint8 prior to saving to suppress this warning.
