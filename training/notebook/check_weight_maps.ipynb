# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../data/unet/family_machine/E_coli_Olga/train/training_data_Ecoli_Olga_erosion_1.npz')

# %%
X_train = data['X_train']
y_train = data['y_train']
weight_maps_train = data['weight_maps_train']

# %%
ix = 120

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.imshow(X_train[ix,:,:,0])
plt.subplot(1,3,2)
plt.imshow(y_train[ix,:,:,0])
plt.subplot(1,3,3)
plt.imshow(weight_maps_train[ix,:,:,0])
plt.colorbar()

# %%
plt.imshow(binary_dilation(binary_dilation(binary_erosion(binary_erosion(y_train[ix,:,:,0])))))
